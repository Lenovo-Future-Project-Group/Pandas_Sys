# %%
import pandas as pd
import chardet

# %%
# Read the Code
def read_the_code(file_path):
    with open(file_path, mode='rb') as f_code:
        encoding = chardet.detect(f_code.read())['encoding']
    return encoding

# %%
# Read the data
def read_the_data(file_path):
    with open(file_path, mode='rb') as f:
        data = f.readlines()

    return data

# %%
dta = read_the_data('Data/dscore.dat')
print(dta)
# Out:
# [b'1.06\x1e\x00\x00\x00\xa6\x00\x00\x003.3.6\x00\x00\x00:\xbe\xd5ef\x94\xda\x88\x01\x02)\x00\x00\x00\xcf\x82T\x80\x1a\xff"\x8d\x90nT\\O\xfbN\xa1R-\x00\x11OP\x00J\x00Y\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...
